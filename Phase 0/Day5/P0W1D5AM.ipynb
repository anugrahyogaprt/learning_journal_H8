# %%
import pandas as pd

data = pd.DataFrame({'col1':['Y','N','3','N','Y','N','Y']})
data
# Out:
#   col1
# 0    Y
# 1    N
# 2    3
# 3    N
# 4    Y
# 5    N
# 6    Y

# %%
data.head(2)
# Out:
#   col1
# 0    Y
# 1    N

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col1    7 non-null      object
# dtypes: object(1)
# memory usage: 184.0+ bytes

# %%
data['col1'].unique()
# Out:
# array(['Y', 'N', '3'], dtype=object)

# %%
data = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/property_data.csv')

# %%
data
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY           12            1      NaN   700
# 4          NaN   203.0    BERKELEY            Y            3        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0     NaN  WASHINGTON          NaN            2   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y           --        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800

# %%
data['OWN_OCCUPIED'].value_counts()
# Out:
# Y     5
# N     2
# 12    1
# Name: OWN_OCCUPIED, dtype: int64

# %%
data.loc[3,'OWN_OCCUPIED'] = 'Y'

# %%
data
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY            Y            1      NaN   700
# 4          NaN   203.0    BERKELEY            Y            3        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0     NaN  WASHINGTON            Y            2   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y           --        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800

# %%
data['NUM_BEDROOMS'] = data['NUM_BEDROOMS'].fillna(3)

# %%
data
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0     NaN   LEXINGTON            N            3        1   850
# 3  100004000.0   201.0    BERKELEY            Y            1      NaN   700
# 4          NaN   203.0    BERKELEY            Y            3        2  1600
# 5  100006000.0   207.0    BERKELEY            Y            3        1   800
# 6  100007000.0     NaN  WASHINGTON            Y            2   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y           --        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800

# %%
data['ST_NUM'].fillna(125,inplace=True)

# %%
data['NUM_BATH'].dropna()
# Out:
# 0         1
# 1       1.5
# 2         1
# 4         2
# 5         1
# 6    HURLEY
# 7         1
# 8         2
# Name: NUM_BATH, dtype: object

# %%
data['OWN_OCCUPIED'].plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-49abb9175249> in <module>()
# ----> 1 data['OWN_OCCUPIED'].plot(kind='bar')
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/core.py in generate(self)
# ...

# %%
data['OWN_OCCUPIED'].value_counts().plot(kind='bar')

# %%
pd.read_csv('https://raw.githubusercontent.com/fahmimnalfrzki/Dataset/main/purchase_data.txt',delimiter=';')
#delimiter = '\t' -> pemisah berupa tab
# Out:
#         user_id                   timestamp      group landing_page  purchased
# 0        851104  2017-01-21 22:11:48.556739    control     old_page          0
# 1        804228  2017-01-12 08:01:45.159739    control     old_page          0
# 2        661590  2017-01-11 16:55:06.154213  treatment     new_page          0
# 3        853541  2017-01-08 18:28:03.143765  treatment     new_page          0
# 4        864975  2017-01-21 01:52:26.210827    control     old_page          1
# ...         ...                         ...        ...          ...        ...
# 294473   751197  2017-01-03 22:28:38.630509    control     old_page          0
# 294474   945152  2017-01-12 00:51:57.078372    control     old_page          0
# 294475   734608  2017-01-22 11:45:03.439544    control     old_page          0
# 294476   697314  2017-01-15 01:20:28.957438    control     old_page          0
# 294477   715931  2017-01-16 12:40:24.467417  treatment     new_page          0
#
# ...

# %%
data1 = pd.read_excel('https://github.com/fahmimnalfrzki/Dataset/blob/main/NMC1-9.xlsx?raw=true',sheet_name='Sheet1')

# %%
data1
# Out:
#        time(s)    V_m  Current (A)  Cycle       Cap
# 0            0  4.098        0.997      1  2.840817
# 1            1  4.096        0.998      1  2.840817
# 2            2  4.094        0.999      1  2.840817
# 3            3  4.093        0.998      1  2.840817
# 4            4  4.092        0.999      1  2.840817
# ...        ...    ...          ...    ...       ...
# 90977    90977  2.506        1.002      9  2.770180
# 90978    90978  2.504        1.002      9  2.770180
# 90979    90979  2.502        1.002      9  2.770180
# 90980    90980  2.500        1.002      9  2.770180
# 90981    90981  2.497        1.002      9  2.770180
#
# [90982 rows x 5 columns]

# %%
data1.drop(index=[0,1],columns=['time(s)','Cycle'],inplace=True)

# %%
data1
# Out:
#          V_m  Current (A)       Cap
# 2      4.094        0.999  2.840817
# 3      4.093        0.998  2.840817
# 4      4.092        0.999  2.840817
# 5      4.091        0.997  2.840817
# 6      4.090        0.996  2.840817
# ...      ...          ...       ...
# 90977  2.506        1.002  2.770180
# 90978  2.504        1.002  2.770180
# 90979  2.502        1.002  2.770180
# 90980  2.500        1.002  2.770180
# 90981  2.497        1.002  2.770180
#
# [90980 rows x 3 columns]
